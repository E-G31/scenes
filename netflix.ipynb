# %%
import pandas as pd
import numpy as np
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-03437026-376f-4e55-8f47-2cc63c4e21aa" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-03437026-376f-4e55-8f47-2cc63c4e21aa">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df=pd.read_csv('netflix_sample_500.csv')

# %%
df.head(10)
# Out:
#                               title          director  \
# 0                   Game Over, Man!    Kyle Newacheck
# 1      Arsenio Hall: Smart & Classy  Brian Volk-Weiss
# 2                          Kazoops!               NaN
# 3              We Are the Champions               NaN
# 4  Pablo Escobar, el patrón del mal               NaN
# 5      Saint Seiya: The Lost Canvas               NaN
# 6                             Fauda               NaN
# 7              The Cook of Castamar               NaN
# 8      The App That Stole Christmas      Monica Floyd
# 9                              Mute      Duncan Jones
#
#                                                 cast                  country  \
# 0  Adam DeVine, Anders Holm, Blake Anderson, Utka...            United States
# 1                                       Arsenio Hall            United States
# 2  Reece Pockney, Scott Langley, Alex Babic, Gemm...                Australia
# ...

# %%
df.shape # number of rows and columns
# Out:
# (500, 7)

# %%
df.columns.tolist() # names of all the columns
# Out:
# ['title',
#  'director',
#  'cast',
#  'country',
#  'date_added',
#  'release_year',
#  'duration']

# %%
pd.concat([df.head(5), df.tail(3)]) # displaying first 5 and last 3 rows
# Out:
#                                 title              director  \
# 0                     Game Over, Man!        Kyle Newacheck
# 1        Arsenio Hall: Smart & Classy      Brian Volk-Weiss
# 2                            Kazoops!                   NaN
# 3                We Are the Champions                   NaN
# 4    Pablo Escobar, el patrón del mal                   NaN
# 497       Korean Cold Noodle Rhapsody                   NaN
# 498                   Look for a Star  Andrew Lau Wai-Keung
# 499                         40 Sticks        Victor Gatonye
#
#                                                   cast        country  \
# 0    Adam DeVine, Anders Holm, Blake Anderson, Utka...  United States
# 1                                         Arsenio Hall  United States
# 2    Reece Pockney, Scott Langley, Alex Babic, Gemm...      Australia
# 3                                                  NaN  United States
# 4    Andrés Parra, Angie Cepeda, Cecilia Navia, Vic...       Colombia
# ...

# %%
df[['title', 'release_year']] #title and release_year
# Out:
#                                 title  release_year
# 0                     Game Over, Man!          2018
# 1        Arsenio Hall: Smart & Classy          2019
# 2                            Kazoops!          2017
# 3                We Are the Champions          2020
# 4    Pablo Escobar, el patrón del mal          2012
# ..                                ...           ...
# 495       Sebastián Marcelo Wainraich          2018
# 496                      The Mistress          2012
# 497       Korean Cold Noodle Rhapsody          2021
# 498                   Look for a Star          2009
# 499                         40 Sticks          2019
#
# [500 rows x 2 columns]

# %%
df.iloc[10:21] # 10 to 20th rows
# Out:
#                                       title                     director  \
# 10                              Drugs, Inc.                          NaN
# 11                           Den of Thieves           Christian Gudegast
# 12                   The President's Barber                Chan-sang Lim
# 13                                 The Dirt                Jeff Tremaine
# 14                           Brews Brothers                          NaN
# 15  Rodney Carrington: Here Comes the Truth                Brandon Jones
# 16                              Planet Hulk                      Sam Liu
# 17                                 Tree Man  Jon Reiner, Brad Rothschild
# 18                             Ladies First                   Uraaz Bahl
# 19                                King Jack               Felix Thompson
# 20                       I love you, stupid                   Laura Mañá
#
#                                                  cast        country  \
# ...

# %%
df.describe()
# Out:
#        release_year
# count    500.000000
# mean    2014.034000
# std        9.507978
# min     1943.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %%
df.count()
# Out:
# title           500
# director        336
# cast            459
# country         454
# date_added      500
# release_year    500
# duration        500
# dtype: int64

# %%
df.isna().sum() # checking for missing values
# Out:
# title             0
# director        164
# cast             41
# country          46
# date_added        0
# release_year      0
# duration          0
# dtype: int64

# %%
df['country']=df['country'].fillna('Unknown')
df['director']=df['director'].fillna('Not Available')# filling missing values

# %%
df['country']=df['country'].str.replace('United States', 'USA') # replacing with USA
df
# Out:
#                                 title                director  \
# 0                     Game Over, Man!          Kyle Newacheck
# 1        Arsenio Hall: Smart & Classy        Brian Volk-Weiss
# 2                            Kazoops!           Not Available
# 3                We Are the Champions           Not Available
# 4    Pablo Escobar, el patrón del mal           Not Available
# ..                                ...                     ...
# 495       Sebastián Marcelo Wainraich  Raúl Campos, Jan Suter
# 496                      The Mistress       Olivia M. Lamasan
# 497       Korean Cold Noodle Rhapsody           Not Available
# 498                   Look for a Star    Andrew Lau Wai-Keung
# 499                         40 Sticks          Victor Gatonye
#
#                                                   cast      country  \
# 0    Adam DeVine, Anders Holm, Blake Anderson, Utka...          USA
# 1                                         Arsenio Hall          USA
# ...

# %%
df['content_type']=df['duration'].apply(lambda x: 'Movie' if 'min' in x else 'TV Show' )

# %%
df.dtypes
# Out:
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# duration        object
# content_type    object
# dtype: object

# %%
df['years_since_release']=2025-df['release_year']
df
# Out:
#                                 title                director  \
# 0                     Game Over, Man!          Kyle Newacheck
# 1        Arsenio Hall: Smart & Classy        Brian Volk-Weiss
# 2                            Kazoops!           Not Available
# 3                We Are the Champions           Not Available
# 4    Pablo Escobar, el patrón del mal           Not Available
# ..                                ...                     ...
# 495       Sebastián Marcelo Wainraich  Raúl Campos, Jan Suter
# 496                      The Mistress       Olivia M. Lamasan
# 497       Korean Cold Noodle Rhapsody           Not Available
# 498                   Look for a Star    Andrew Lau Wai-Keung
# 499                         40 Sticks          Victor Gatonye
#
#                                                   cast      country  \
# 0    Adam DeVine, Anders Holm, Blake Anderson, Utka...          USA
# 1                                         Arsenio Hall          USA
# ...

# %%
df.groupby(['release_year']).size()
# Out:
# release_year
# 1943     1
# 1954     1
# 1960     1
# 1962     1
# 1963     1
# 1969     1
# 1973     1
# 1976     1
# 1978     1
# 1979     2
# 1981     1
# 1982     1
# 1985     1
# 1986     2
# 1988     1
# 1990     1
# 1991     1
# 1992     1
# 1993     2
# 1994     1
# 1996     2
# 1998     3
# 1999     1
# 2001     2
# 2002     2
# 2003     2
# 2004     3
# 2005     1
# 2006     6
# 2007     8
# 2008     7
# 2009    14
# 2010    13
# 2011     8
# 2012    12
# 2013    20
# 2014    26
# 2015    29
# 2016    55
# 2017    57
# 2018    75
# 2019    47
# 2020    45
# 2021    39
# dtype: int64

# %%
tv_shows=df[df['content_type']=='TV Show'].groupby('release_year').size()
tv_shows
# Out:
# release_year
# 1963     1
# 1993     1
# 1998     1
# 2002     1
# 2004     1
# 2006     1
# 2007     1
# 2008     1
# 2009     4
# 2010     3
# 2012     4
# 2013     5
# 2014    10
# 2015    11
# 2016    14
# 2017    19
# 2018    24
# 2019    21
# 2020    24
# 2021    20
# dtype: int64

# %%
df['split']=df['country'].str.split(', ')
df_exploded=df.explode('split')
df_exploded['split'].value_counts()
# Out:
# split
# USA                     204
# India                    59
# Unknown                  46
# United Kingdom           36
# Japan                    23
# Canada                   23
# France                   22
# South Korea              16
# Spain                    16
# Germany                  14
# China                    13
# Australia                12
# Mexico                   11
# Turkey                    9
# Hong Kong                 8
# Brazil                    8
# Indonesia                 7
# Taiwan                    6
# Nigeria                   5
# Israel                    5
# Belgium                   5
# Philippines               4
# Poland                    4
# Colombia                  3
# Thailand                  3
# Argentina                 3
# South Africa              3
# Ireland                   3
# Egypt                     3
# United Arab Emirates      3
# Finland                   2
# Italy                     2
# Uruguay                   2
# ...
